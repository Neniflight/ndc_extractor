# %%
import pandas as pd
import numpy as np
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import nltk

# %%
# Read in the data from Tom's output
data = pd.read_csv("../Output/20240416_02_NDC_sentences.csv")
data['text_content'] = data['text_content'].astype(str)

keywords = pd.read_csv("../Data/keywords_for_marine_policy.csv")
keywords
# Out:
#              Topic                          Keyword
# 0   climate change                   global warming
# 1   climate change                    ocean warming
# 2   climate change                    acidification
# 3   climate change                   sea-level rise
# 4   climate change                    deoxygenation
# ..             ...                              ...
# 85          policy  small island developing nations
# 86          policy                             SIDS
# 87          policy                     jurisdiction
# 88          policy                      enforcement
# 89          policy                  disaster relief
#
# [90 rows x 2 columns]

# %%
data.shape
# Out:
# (186837, 11)

# %%
stemmer = PorterStemmer()

stemmed_keywords = set([stemmer.stem(keyword) for keyword in keywords["Keyword"]])
stemmed_keywords
# Out:
# {'acidif',
#  'alga',
#  'algal bloom',
#  'antarct',
#  'aquacultur',
#  'arctic',
#  'bentho',
#  'blue carbon',
#  'bycatch',
#  'coast',
#  'coastal develop',
#  'commercial ship',
#  'conserv',
#  'contamin',
#  'coral',
#  'deep ocean',
#  'deoxygen',
#  'disaster relief',
#  'ecotour',
#  'endangered speci',
#  'enforc',
#  'estuari',
#  'eutroph',
#  'exploit',
#  'fertil',
#  'fish',
#  'frack',
#  'fund',
#  'global warm',
#  'habitat loss',
#  'heavy met',
#  'hurrican',
#  'hypoxia',
#  'ice melt',
#  'international wat',
#  'jurisdict',
#  'justic',
#  'kelp forest',
#  'law',
#  'long-line fisheri',
#  'mangrov',
#  'marin',
#  'marine mamm',
#  'marine protected area',
#  'marine research',
#  'maritim',
#  'marsh',
#  'microplast',
#  'natural disast',
#  'ocean',
#  'ocean warm',
#  'offshor',
#  'offshore wind',
#  'oil',
#  'oil dril',
#  'oil spil',
#  'overfish',
#  'oxygen',
#  'pelag',
#  'persistant organic pollut',
#  'plankton',
#  'plastic',
#  'protected speci',
#  'reef',
#  'resource manag',
#  'sanit',
#  'sargassum',
#  'sea',
#  'sea-level',
#  'sea-level ris',
#  'seabird',
#  'seafood industri',
#  'seagrass',
#  'sediment',
#  'sewag',
#  'sid',
#  'small island developing n',
#  'sustan',
#  'trawl',
#  'tsunami',
#  'turbid',
#  'underwater nois',
#  'wastewat',
#  'wetland'}

# %% [markdown]
# # Issue
# The output from Tom's script is good, but there are couple data quality issues that need to be addressed
# * Some sentences are **split** across multiple cells when they should not be
# * Some text_content is literally just punctation and numbers
#
# # Solution
# * Combine the cells if possible
# * Remove if text content is less than 5 and does not contain keyword

# %%
def contains_stemmed_word(text):
    if len(text) > 5:
        return True
    else:
        for word in stemmed_keywords:
            if word in text:
                return True
        return False

# %%
data = data[data['text_content'].apply(contains_stemmed_word)]
# Here we removed approximately 20k rows from the dataframe 
# if the text content was < 5 characters and did not contain a keyword
data = data.reset_index(drop=True)

# %%
data.shape
# Out:
# (165102, 11)

# %%
"""
Description: used to combine cells on a dataframe 
Input:
* df: Dataframe object
* rows: list of indices of the rows that should be combined

Output:
* new_row: a series containin the combined text_content from the rows. 
"""
def cell_merger(df, rows):
    new_row = df.loc[rows[0], ['iso', 'country', 'ndc', 'date', 'html', 'text_type', 'h1_text', 'h2_text', 'h3_text', 'h4_text']]
    new_row['text_content'] = " ".join([df.loc[row_i, 'text_content'] for row_i in rows])
    return new_row

# %%
"""
Description: Create a list of lists that record the cells that should be combined to make complete sentences in text_content
"""
def incomplete_cells(df):
    indices_lst = [] # stores a list of lists the indices of cells that can be merged
    i = 0
    through_lst = [] # stores an smaller lst of indices of cells that can be merged
    curr_sen = False
    first_cell_sentence = True
    while i < len(df['text_content']): # iterate through indices
        curr_text = df.loc[i, 'text_content'] # curr text
        # print(i) # to track curr index
        if not curr_text[0].isalpha(): # if first char is not a letter then we continue
            i += 1
            continue
        # if we currently are going through a sentence but we encounter a capital letter or a non alphabet letter
        # then we break the sentence and append it to the indices lst
        if curr_sen and (curr_text[0].isupper() or (not curr_text[0].isalpha())):
            indices_lst.append(through_lst)
            through_lst = []
            curr_sen = False
            first_cell_sentence = True
            i += 1
            continue
        # if we encounter a lower case letter we should append it to through_lst!
        if not curr_text[0].isupper() and curr_text[1] not in set([".", ")"]):
            curr_sen = True
            # also append the previous index because that also needs to be combined (i.e. first cell would contain "Sustainable technology is" and the curr cell would have "very vital")
            if first_cell_sentence:
                through_lst.append(i - 1)
                # we dont want to append twice after the first append. 
                first_cell_sentence = False
            through_lst.append(i)
            i+= 1
            continue
        i += 1
    return indices_lst

# %%
def df_cleaner(df):
    df = df.copy()
    # create the list of lists of cells to combine
    to_be_combined_lst = incomplete_cells(data)
    for lst in to_be_combined_lst:
        # print(lst)
        row = cell_merger(df, lst)
        df.loc[lst[0]] = row 
        df = df.drop(lst[1:])
    return df

# %%
cleaned_df = df_cleaner(data)
cleaned_df.shape
# Out:
# (161031, 11)

# %% [markdown]
# We approximately erased 6000 cells and made cells that were separated to combine into proper sentences.

# %%
cleaned_df = cleaned_df.reset_index(drop = True)
cleaned_df.head(10)
# Out:
#    iso      country  ndc      date                   html text_type  \
# 0  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html         p
# 1  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html         p
# 2  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html     table
# 3  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html     table
# 4  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html        ul
# 5  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html         p
# 6  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html         p
# 7  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html         p
# 8  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html         p
# 9  AFG  Afghanistan    1  11/23/16  AFG-first_ndc-EN.html         p
#
#                                         text_content  \
# 0                                  21 September 2015
# 1  The Islamic Republic of Afghanistan hereby com...
# 2  Base Year: 2005 Target Years: 2020 to 2030 Con...
# 3  Financial Needs: Total: USD 17.405 billionAdap...
# 4  Adaptation: USD 10.785 billion Mitigation: USD...
# 5                                          Figure 1.
# 6  Greenhouse Gas Emissions for Afghanistan showi...
# 7  Afghanistan has extensive development and clim...
# 8  Afghanistan remains one of the poorest countri...
# 9  Afghanistan is highly prone to natural disaste...
#
#                                        h1_text  \
# 0  Intended Nationally Determined Contribution
# 1  Intended Nationally Determined Contribution
# 2  Intended Nationally Determined Contribution
# 3  Intended Nationally Determined Contribution
# 4  Intended Nationally Determined Contribution
# 5  Intended Nationally Determined Contribution
# 6  Intended Nationally Determined Contribution
# 7  Intended Nationally Determined Contribution
# 8  Intended Nationally Determined Contribution
# 9  Intended Nationally Determined Contribution
#
#                                              h2_text  \
# 0  Submission to the United Nations Framework Con...
# 1  Submission to the United Nations Framework Con...
# 2  Submission to the United Nations Framework Con...
# 3  Submission to the United Nations Framework Con...
# 4  Submission to the United Nations Framework Con...
# 5  Submission to the United Nations Framework Con...
# 6  Submission to the United Nations Framework Con...
# 7  Submission to the United Nations Framework Con...
# 8  Submission to the United Nations Framework Con...
# 9  Submission to the United Nations Framework Con...
#
#                                              h3_text       h4_text
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
# 5                                                NaN           NaN
# 6                                                NaN           NaN
# 7  1. Afghanistan’s National Circumstances and Co...  Introduction
# 8  1. Afghanistan’s National Circumstances and Co...  Introduction
# 9  1. Afghanistan’s National Circumstances and Co...  Introduction

# %%
cleaned_df.to_csv("../Output/20240419_CN_NDC_sentences_qc.csv", index=False)
