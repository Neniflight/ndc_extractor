# %%
# !pip install pandas beautifulsoup4 lxml nltk
# Out:
# Requirement already satisfied: pandas in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: beautifulsoup4 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (4.12.2)
# Requirement already satisfied: lxml in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (5.2.1)
# Requirement already satisfied: nltk in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (3.8.1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: click in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from nltk) (2024.4.16)
# Requirement already satisfied: tqdm in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from nltk) (4.66.2)
# Requirement already satisfied: six>=1.5 in /Users/twc/opt/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# Directory and file setup
directory_path = '/Users/twc/Research/20221022_Updated_NDCs/Data/20240117_ClimateWatch_AllData/NDC_text_HTML/ndc-master'
file_path = '/Users/twc/Research/20221022_Updated_NDCs/Data/20240118_countries.csv'
data = pd.read_csv(file_path)

# List to hold content
html_contents = []

# Load and parse HTML files
for filename in data['Climate.Watch.HTML.File']:
    full_path = os.path.join(directory_path, filename)
    if os.path.exists(full_path):
        with open(full_path, 'r', encoding='utf-8') as file:
            soup = BeautifulSoup(file, 'lxml')
            html_contents.append(soup)
    else:
        html_contents.append(None)

# Function to find the closest preceding h1, h2, h3, h4 for any tag and replace line breaks
def find_preceding_tags(tag):
    previous_elements = tag.find_all_previous()
    found_tags = {}
    for element in previous_elements:
        if element.name in ['h1', 'h2', 'h3', 'h4'] and element.name not in found_tags:
            text = element.get_text(strip=True).replace('\n', ' ').replace('\r', ' ')
            found_tags[element.name] = text
        if len(found_tags) == 4:
            break
    return found_tags  # Returns a dictionary of the found headings

def extract_text(tag):
    if tag.name == 'table':
        return ' '.join([cell.get_text(strip=True).replace('\n', ' ').replace('\r', ' ') for cell in tag.find_all('td')])
    elif tag.name in ['ol', 'ul']:
        return ' '.join([item.get_text(strip=True).replace('\n', ' ').replace('\r', ' ') for item in tag.find_all('li')])
    else:  # 'p' and other direct text containers
        return tag.get_text(strip=True).replace('\n', ' ').replace('\r', ' ')

# Extracting data
all_data = []
for i, soup in enumerate(html_contents):
    if soup is not None:
        tags = soup.find_all(['p', 'ol', 'ul', 'table'])
        for tag in tags:
            tag_text = extract_text(tag)
            headings = find_preceding_tags(tag)
            all_data.append({
                'iso': data.loc[i, 'ISO'],
                'country': data.loc[i, 'Country'],
                'ndc': data.loc[i, 'NDC'],
                'date': data.loc[i, 'Date'],
                'html': data.loc[i, 'Climate.Watch.HTML.File'],
                'text_type': tag.name,
                'text_content': tag_text,
                'h1_text': headings.get('h1', None),
                'h2_text': headings.get('h2', None),
                'h3_text': headings.get('h3', None),
                'h4_text': headings.get('h4', None),
            })

# Create DataFrame
df_elements = pd.DataFrame(all_data)
print(df_elements)

elements_file_path = '/Users/twc/Research/20221022_Updated_NDCs/Output/20240416_02_NDC_elements.csv'
df_elements.to_csv(elements_file_path, index=False)
# Out:
#         iso      country  ndc      date                           html  \
# 0       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 1       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 2       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 3       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 4       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# ...     ...          ...  ...       ...                            ...
# 114017  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114018  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114019  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114020  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114021  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
#
#        text_type                                       text_content  \
# 0              p                                  21 September 2015
# 1              p  The Islamic Republic of Afghanistan hereby com...
# 2          table  Base Year: 2005 Target Years: 2020 to 2030 Con...
# 3             ul  Adaptation: USD 10.785 billion Mitigation: USD...
# 4              p  Figure 1. Greenhouse Gas Emissions for Afghani...
# ...          ...                                                ...
# 114017         p                       11th Floor, Kaguvi Building,
# 114018         p  Cnr S.V Muzenda Street/ Central Avenue, Harare...
# 114019         p                           Tel: +263 (242) 701681/3
# 114020         p  Email:climatechange@environment.gov.zw Website...
# 114021        ol  Global GHG emissions including land-use change...
#
#                                             h1_text  \
# 0       Intended Nationally Determined Contribution
# 1       Intended Nationally Determined Contribution
# 2       Intended Nationally Determined Contribution
# 3       Intended Nationally Determined Contribution
# 4       Intended Nationally Determined Contribution
# ...                                             ...
# 114017                       GOVERNMENT OF ZIMBABWE
# 114018                       GOVERNMENT OF ZIMBABWE
# 114019                       GOVERNMENT OF ZIMBABWE
# 114020                       GOVERNMENT OF ZIMBABWE
# 114021                       GOVERNMENT OF ZIMBABWE
#
#                                                   h2_text      h3_text  \
# 0       Submission to the United Nations Framework Con...         None
# 1       Submission to the United Nations Framework Con...         None
# 2       Submission to the United Nations Framework Con...         None
# 3       Submission to the United Nations Framework Con...         None
# 4       Submission to the United Nations Framework Con...         None
# ...                                                   ...          ...
# 114017  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114018  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114019  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114020  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114021  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
#
#                                      h4_text
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 114017  Tracking climate finance in Zimbabwe
# 114018  Tracking climate finance in Zimbabwe
# 114019  Tracking climate finance in Zimbabwe
# 114020  Tracking climate finance in Zimbabwe
# 114021  Tracking climate finance in Zimbabwe
#
# [114022 rows x 11 columns]

# %%
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize

# Assuming df_elements is already loaded with the necessary data

# Downloading the required resource for nltk
nltk.download('punkt')

# Function to split text into sentences
def split_into_sentences(text):
    return sent_tokenize(text)

# Expanding the DataFrame to include a row per sentence
all_rows = []
for _, row in df_elements.iterrows():
    sentences = split_into_sentences(row['text_content'])
    for sentence in sentences:
        new_row = row.copy()
        new_row['text_content'] = sentence
        all_rows.append(new_row)

# Create new DataFrame
df_sentences = pd.DataFrame(all_rows)

print(df_sentences)

sentences_file_path = '/Users/twc/Research/20221022_Updated_NDCs/Output/20240416_02_NDC_sentences.csv'
df_sentences.to_csv(sentences_file_path, index=False)
# Out:
# [nltk_data] Downloading package punkt to /Users/twc/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#         iso      country  ndc      date                           html  \
# 0       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 1       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 2       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 2       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# 3       AFG  Afghanistan    1  11/23/16          AFG-first_ndc-EN.html
# ...     ...          ...  ...       ...                            ...
# 114021  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114021  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114021  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114021  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
# 114021  ZWE     Zimbabwe    2   9/24/21  ZWE-revised_first_ndc-EN.html
#
#        text_type                                       text_content  \
# 0              p                                  21 September 2015
# 1              p  The Islamic Republic of Afghanistan hereby com...
# 2          table  Base Year: 2005 Target Years: 2020 to 2030 Con...
# 2          table  Financial Needs: Total: USD 17.405 billionAdap...
# 3             ul  Adaptation: USD 10.785 billion Mitigation: USD...
# ...          ...                                                ...
# 114021        ol  emissions removals were greater than emissions...
# 114021        ol  This change is due to the fact that the previo...
# 114021        ol  Zimbabwe is now using updated data on emission...
# 114021        ol                           Gender Analysis of NDCs.
# 114021        ol  Draft.↩ Government of Zimbabwe Financial and M...
#
#                                             h1_text  \
# 0       Intended Nationally Determined Contribution
# 1       Intended Nationally Determined Contribution
# 2       Intended Nationally Determined Contribution
# 2       Intended Nationally Determined Contribution
# 3       Intended Nationally Determined Contribution
# ...                                             ...
# 114021                       GOVERNMENT OF ZIMBABWE
# 114021                       GOVERNMENT OF ZIMBABWE
# 114021                       GOVERNMENT OF ZIMBABWE
# 114021                       GOVERNMENT OF ZIMBABWE
# 114021                       GOVERNMENT OF ZIMBABWE
#
#                                                   h2_text      h3_text  \
# 0       Submission to the United Nations Framework Con...         None
# 1       Submission to the United Nations Framework Con...         None
# 2       Submission to the United Nations Framework Con...         None
# 2       Submission to the United Nations Framework Con...         None
# 3       Submission to the United Nations Framework Con...         None
# ...                                                   ...          ...
# 114021  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114021  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114021  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114021  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
# 114021  7 Information for Clarity, Transparency and Un...  4.6.4 Waste
#
#                                      h4_text
# 0                                       None
# 1                                       None
# 2                                       None
# 2                                       None
# 3                                       None
# ...                                      ...
# 114021  Tracking climate finance in Zimbabwe
# 114021  Tracking climate finance in Zimbabwe
# 114021  Tracking climate finance in Zimbabwe
# 114021  Tracking climate finance in Zimbabwe
# 114021  Tracking climate finance in Zimbabwe
#
# [186837 rows x 11 columns]
